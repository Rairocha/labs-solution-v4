# %% [markdown]
# # Lab | Web Scraping

# %% [markdown]
# Welcome to the IMDb Web Scraping Adventure Lab!
#
# **Objective**
#
# In this lab, we will embark on a mission to unearth valuable insights from the vast sea of data available on IMDb, one of the largest online databases of movie, TV, and celebrity information. As budding data scientists and business analysts, you have been tasked to scrape a specific subset of data from IMDb to assist film production companies in understanding the landscape of highly-rated movies in a defined time period. Your insights will potentially influence the making of the next netflix movie!
#
# **Background**
#
# In a world where data has become the new currency, businesses are leveraging big data to make informed decisions that drive success and profitability. The entertainment industry, being no exception, utilizes data analytics to comprehend market trends, audience preferences, and the performance of films based on various parameters such as director, genre, stars involved, etc. IMDb stands as a goldmine of such data, offering intricate details of almost every movie ever made.
#
# **Task**
#
# Your task is to create a Python script using `BeautifulSoup` and `pandas` to scrape IMDb movie data based on user ratings and release dates. This script should be able to filter movies with ratings above a certain threshold and within a specified date range.
#
# **Expected Outcome**
#
# - A function named `scrape_imdb` that takes four parameters: `title_type`,`user_rating`, `start_date`, and `end_date`.
# - The function should return a DataFrame with the following columns:
#   - **Movie Nr**: The number representing the movie’s position in the list.
#   - **Title**: The title of the movie.
#   - **Year**: The year the movie was released.
#   - **Rating**: The IMDb rating of the movie.
#   - **Runtime (min)**: The duration of the movie in minutes.
#   - **Genre**: The genre of the movie.
#   - **Description**: A brief description of the movie.
#   - **Director**: The director of the movie.
#   - **Stars**: The main stars of the movie.
#   - **Votes**: The number of votes the movie received.
#   - **Gross ($M)**: The gross earnings of the movie in millions of USD.
#
# You will execute this script to scrape data for movies with the Title Type `Feature Film` that have a user rating of `7.5 and above` and were released between `January 1, 1990, and December 31, 1992`.
#
# Remember to experiment with different title types, dates and ratings to ensure your code is versatile and can handle various searches effectively!
#
# **Resources**
#
# - [Beautiful Soup Documentation](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Pandas Documentation](https://pandas.pydata.org/pandas-docs/stable/index.html)
# - [IMDb Advanced Search](https://www.imdb.com/search/title/)

# %%
#Connect (sucessfully) with the website - requests
#Transforming the data from string to searchable object - make the soup!
#Find out what data I need and locate it in the website -  soup.find_all or soup.select
#Transform data to put it in a dataframe - pd.DataFrame
#Create the spider to apply code for several pages - for loop

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
from datetime import datetime

# %%
#Connect (sucessfully) with the website - requests
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}

title_type='Short'
user_rating = 7.5
start_date='January 1, 1990'
end_date ='December 31, 1992'

title_type_clean = title_type.lower().strip().replace(' ','_')
date_time_start = datetime.strptime(start_date,'%B %d, %Y')
string_start = datetime.strftime(date_time_start,"%Y-%m-%d")
date_time_end = datetime.strptime(end_date,'%B %d, %Y')
string_end = datetime.strftime(date_time_end,"%Y-%m-%d")

url=f'https://www.imdb.com/search/title/?title_type={title_type_clean}&user_rating={user_rating},10&release_date={string_start},{string_end}'


response = requests.get(url,headers=headers)
response.content
# Out:
# b'<!DOCTYPE html><html lang="en-US" xmlns:og="http://opengraphprotocol.org/schema/" xmlns:fb="http://www.facebook.com/2008/fbml"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitle\', {wb: 1}); }</script><script>window.addEventListener(\'load\', (event) => {\n        if (typeof window.csa !== \'undefined\' && typeof window.csa === \'function\') {\n            var csaLatencyPlugin = window.csa(\'Content\', {\n                element: {\n                    slotId: \'LoadTitle\',\n                    type: \'service-call\'\n                }\n            });\n            csaLatencyPlugin(\'mark\', \'clickToBodyBegin\', 1702313383591);\n        }\n    })</script><title>Advanced search</title><meta name="description" content="" data-id="main"/><meta property="og:url" content="https://www.imdb.com/search/"/><meta property="og:site_name" content="IMDb"/><meta property="og:title" content="Advanced search"/><meta property="og:description" content=""/><meta property="og:type" content="website"/><meta property="og:image" content="https://m.media-amazon.com/images/G/01/imdb/images/social/imdb_logo.png"/><meta property="og:image:height" content="1000"/><meta property="og:image:width" content="1000"/><meta content="en_US" property="og:locale"/><meta content="es_ES" property="og:locale:alternate"/><meta content="es_MX" property="og:locale:alternate"/><meta content="fr_FR" property="og:locale:alternate"/><meta content="fr_CA" property="og:locale:alternate"/><meta content="it_IT" property="og:locale:alternate"/><meta content="pt_BR" property="og:locale:alternate"/><meta content="hi_IN" property="og:locale:alternate"/><meta content="de_DE" property="og:locale:alternate"/><meta property="twitter:site" content="@IMDb"/><meta property="twitter:title" content="Advanced search"/><meta property="twitter:description" content=""/><meta property="twitter:card" content="summary_large_image"/><meta property="twitter:image" content="https://m.media-amazon.com/images/G/01/imdb/images/social/imdb_logo.png"/><meta property="twitter:image:alt" content=""/><link rel="canonical" href="https://www.imdb.com/search/"/><meta property="imdb:pageType" content="advsearch"/><meta property="imdb:subPageType" content="title"/><script>if(typeof uet === \'function\'){ uet(\'be\', \'LoadTitle\', {wb: 1}); }</script><script>window.addEventListener(\'load\', (event) => {\n        if (typeof window.csa !== \'undefined\' && typeof window.csa === \'function\') {\n            var csaLatencyPlugin = window.csa(\'Content\', {\n                element: {\n                    slotId: \'LoadTitle\',\n                    type: \'service-call\'\n                }\n            });\n            csaLatencyPlugin(\'mark\', \'clickToBodyEnd\', 1702313383591);\n        }\n    })</script><script>if(typeof uex === \'function\'){ uex(\'ld\', \'LoadTitle\', {wb: 1}); }</script><script>window.addEventListener(\'load\', (event) => {\n        if (typeof window.csa !== \'undefined\' && typeof window.csa === \'function\') {\n            var csaLatencyPlugin = window.csa(\'Content\', {\n                element: {\n                    slotId: \'LoadTitle\',\n                    type: \'service-call\'\n                }\n            });\n            csaLatencyPlugin(\'mark\', \'clickToLoaded\', 1702313383591);\n        }\n    })</script><meta name="next-head-count" content="36"/><script>\nvar ue_t0=ue_t0||+new Date();\n\nwindow.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;\nif (window.ue_ihb === 1) {\n\nvar ue_csm = window,\n    ue_hob = +new Date();\n(function(d){var e=d.ue=d.ue||{},f=Date.now||function(){return+new Date};e.d=function(b){return f()-(b?0:d.ue_t0)};e.stub=function(b,a){if(!b[a]){var c=[];b[a]=function(){c.push([c.slice.call(arguments),e.d(),d.ue_id])};b[a].replay=function(b){for(var a;a=c.shift();)b(a[0],a[1],a[2])};b[a].isStub=1}};e.exec=function(b,a){return function(){try{return b.apply(t ...

# %% [raw]
# https://docs.python.org/3/library/datetime.html

# %%
dict_months={'January':'01','December':'12'}
test = start_date.replace(',','').split(' ')
year = test[2]
day = test[1].zfill(2)
month = dict_months[test[0]]
start_clean =f'{year}-{month}-{day}'
start_clean
# Out:
# '1990-01-01'

# %%
date_time_start = datetime.strptime(start_date,'%B %d, %Y')
string_start = datetime.strftime(date_time_start,"%Y-%m-%d")
date_time_end = datetime.strptime(end_date,'%B %d, %Y')
string_end = datetime.strftime(date_time_end,"%Y-%m-%d")

# %%
#Transforming the data from string to searchable object - make the soup!
soup = BeautifulSoup(response.content)
soup.select('h1')
# Out:
# [<h1 class="ipc-title__text">Advanced search</h1>]

# %%
#Find out what data I need and locate it in the website -  soup.find_all or soup.select
title_position = soup.find_all('h3')[:-1]
position = [t.text.split('.')[0] for t in title_position]
title = [t.text.split('. ',1)[1] for t in title_position]
years = [div.find('span').text for div in soup.find_all('div',attrs={'class':'sc-43986a27-7 dBkaPT dli-title-metadata'})]
title_urls = ['https://www.imdb.com' + u.get('href') for u in soup.select('a.ipc-title-link-wrapper')]
votes = [div.text.replace('Votes','').replace(',','') for div in soup.find_all('div', class_="sc-53c98e73-0 kRnqtn")]
runtime = []
for div in soup.find_all('div',attrs={'class':"sc-43986a27-7 dBkaPT dli-title-metadata"}):
    try:
        runtime.append(div.find_all('span')[1].text)
    except:
        runtime.append(None)

description =[]
for l in soup.find_all('li',attrs={'class':"ipc-metadata-list-summary-item"}):
    try:
        description.append(l.find('div', attrs={'class':"ipc-html-content-inner-div"}).text)
    except:
        description.append(None)
stars = [stars.get('aria-label').split(': ')[1] for stars in soup.find_all('span',attrs ={'class':"ipc-rating-star ipc-rating-star--base ipc-rating-star--imdb ratingGroup--imdb-rating"})]
#stars = [stars.text for stars in soup.find_all('div',attrs={'class':"sc-e3e7b191-0 jlKVfJ sc-43986a27-2 bvCMEK dli-ratings-container"})]

# %%
#Transform data to put it in a dataframe - pd.DataFrame
df = pd.DataFrame({'Position':position,'Title':title,'Year of Release':years,
             'Votes':votes,'Runtime':runtime,'Decription':description,
              'Stars':stars,'URL':title_urls})
df
# Out:
#    Position                                           Title Year of Release  \
# 0         1                          Mr. Bean Takes an Exam            1991
# 1         2                                       Knock Out            1992
# 2         3                                     Anima Mundi            1991
# 3         4                                Härlig är jorden            1991
# 4         5                                        12:01 PM            1990
# 5         6                                  Jacob's Ladder            1990
# 6         7                                          Comida            1992
# 7         8                                Purple Triangles            1991
# 8         9                                 Big House Blues            1990
# 9        10            Sadako and the Thousand Paper Cranes            1991
# 10       11                                      Fantasmic!            1992
# 11       12                    O Sonho de um Homem Ridículo            1992
# 12       13                                De kut van Maria            1991
# 13       14                                 Days of Waiting            1991
# 14       15                               Muppet*vision 3-D            1991
# 15       16                     Mr. Bean Goes to a Première            1991
# 16       17                      Konec stalinismu v Cechách            1991
# 17       18                              Die schwarze Sonne            1992
# 18       19                       Stanley and the Dinosaurs            1990
# 31  https://www.imdb.com/title/tt14311920/?ref_=sr...
# 32  https://www.imdb.com/title/tt1262901/?ref_=sr_...
# 33  https://www.imdb.com/title/tt0447704/?ref_=sr_...
# 34  https://www.imdb.com/title/tt0100090/?ref_=sr_...
# 35  https://www.imdb.com/title/tt0125668/?ref_=sr_...
# 36  https://www.imdb.com/title/tt0782686/?ref_=sr_...
# 37  https://www.imdb.com/title/tt0284364/?ref_=sr_...
# 38  https://www.imdb.com/title/tt0212637/?ref_=sr_...
# 39  https://www.imdb.com/title/tt8455642/?ref_=sr_...
# 40  https://www.imdb.com/title/tt0387611/?ref_=sr_...
# 41  https://www.imdb.com/title/tt3991130/?ref_=sr_...
# 42  https://www.imdb.com/title/tt0095571/?ref_=sr_...
# 43  https://www.imdb.com/title/tt0240833/?ref_=sr_...
# 44  https://www.imdb.com/title/tt0480482/?ref_=sr_...
# 45  https://www.imdb.com/title/tt0145709/?ref_=sr_...
# 46  https://www.imdb.com/title/tt0417151/?ref_=sr_...
# 47  https://www.imdb.com/title/tt0137348/?ref_=sr_...
# 48  https://www.imdb.com/title/tt0103301/?ref_=sr_...
# 49  https://www.imdb.com/title/tt5096888/?ref_=sr_...

# %%
def scrape_imdb(title_type,user_rating,start_date,end_date):
    title_type_clean = title_type.lower().strip().replace(' ','_')
    date_time_start = datetime.strptime(start_date,'%B %d, %Y')
    string_start = datetime.strftime(date_time_start,"%Y-%m-%d")
    date_time_end = datetime.strptime(end_date,'%B %d, %Y')
    string_end = datetime.strftime(date_time_end,"%Y-%m-%d")
    
    url=f'https://www.imdb.com/search/title/?title_type={title_type_clean}&user_rating={user_rating},10&release_date={string_start},{string_end}'
    
    
    response = requests.get(url,headers=headers)
    soup = BeautifulSoup(response.content)
    title_position = soup.find_all('h3')[:-1]
    position = [t.text.split('.')[0] for t in title_position]
    title = [t.text.split('. ',1)[1] for t in title_position]
    years = [div.find('span').text for div in soup.find_all('div',attrs={'class':'sc-43986a27-7 dBkaPT dli-title-metadata'})]
    title_urls = ['https://www.imdb.com' + u.get('href') for u in soup.select('a.ipc-title-link-wrapper')]
    votes = [div.text.replace('Votes','').replace(',','') for div in soup.find_all('div', class_="sc-53c98e73-0 kRnqtn")]
    runtime = []
    for div in soup.find_all('div',attrs={'class':"sc-43986a27-7 dBkaPT dli-title-metadata"}):
        try:
            runtime.append(div.find_all('span')[1].text)
        except:
            runtime.append(None)
    
    description =[]
    for l in soup.find_all('li',attrs={'class':"ipc-metadata-list-summary-item"}):
        try:
            description.append(l.find('div', attrs={'class':"ipc-html-content-inner-div"}).text)
        except:
            description.append(None)
    stars = [stars.get('aria-label').split(': ')[1] for stars in soup.find_all('span',attrs ={'class':"ipc-rating-star ipc-rating-star--base ipc-rating-star--imdb ratingGroup--imdb-rating"})]
    #stars = [stars.text for stars in soup.find_all('div',attrs={'class':"sc-e3e7b191-0 jlKVfJ sc-43986a27-2 bvCMEK dli-ratings-container"})]
    df = pd.DataFrame({'Position':position,'Title':title,'Year of Release':years,
                 'Votes':votes,'Runtime':runtime,'Decription':description,
                  'Stars':stars,'URL':title_urls})
    return df

# %%
scrape_imdb('TV Movie',9,'January 1, 1990','December 31, 1992')
# Out:
#    Position                                           Title Year of Release  \
# 0         1                                 Tudo em Família            1991
# 1         2                                   Boris Godunov            1990
# 2         3                                     Animal Park            1991
# 3         4                                 The White River            1992
# 4         5  C.A.N.D.L.E.S.: The Story of the Mengele Twins            1990
# 5         6                               Brer Rabbit Tales            1991
# 6         7                             Wings Over the Gulf            1992
# 7         8                      Realms of the Russian Bear            1992
# 8         9                           The Steven Banks Show            1991
# 9        10                                Gjuetia e fundit            1992
# 10       11                                   Das Rheingold            1992
# 11       12                             Kleiner König Erich            1990
# 12       13                           A Matter of Principal            1990
# 13       14                             Nelson and Jeanette            1992
# 14       15                                           Kulla            1991
# 15       16                                            Baal            1990
# 16       17                                  Hamburger Gift            1992
# 17       18                                Mutter und Söhne            1992
# 18       19                                 Priyo Podorekha            1992
# 19       20                          Kabare Milana Gutovica            1992
# 20       21                               Aaj Amader Chhuti            1992
# 21       22                Splendors of the Ottoman Sultans            1992
# 22       23                                        Djelidba            1991
# 23       24                                   Working Title            1992
# 24       25                                        Sibirien            1991
# 25       26                  Journey to the Forgotten River            1990
# 26       27                                  Songs Are Free            1991
# 27       28          Johannes Brahms: Symphony No. 1 op. 68            1991
# 28       29                                         ...Hofi            1991
# 29       30                            20 jaar Gaston & Leo            1992
# 30       31                                        Dioskuri            1991
# 31       32                  The Rough South of Harry Crews            1991
# 32       33                                           Tosca            1990
#
#    Votes Runtime                                         Decription Stars  \
# 0     48    None  Cast members as well as viewers share what the...   9.1
# 1     72  3h 30m  This is the Andrei Tarkovsky production of the...   9.0
# 2      9     30m                                               None   9.0
# 3     37    None                                               None   9.3
# 4      9     53m  60-minute t.v. documentary follows the survivi...   9.0
# 5     13     47m  Tales of fun, excitement and laughter, revolvi...   9.0
# 6      7      3h                                               None   9.5
# 7     35     50m              A natural history of the former USSR.   9.0
# 8     81     30m                                               None   9.3
# 9     14    None                                               None   9.3
# 10    46    None                                               None   9.3
# 11     9  1h 30m                                               None   9.1
# 12     9    None  The struggles of a principal at an elementary ...   9.0
# 13    40     57m  A retrospect of Nelson Eddy and Jeanette MacDo...   9.1
# 14    37    None                                               None   9.3
# 15    16    None                                               None   9.3
# 16     9  1h 30m  A docu-drama about tetrachloro-dibenzo dioxin,...   9.0
# 17     9  1h 30m                                               None   9.8
# 18    13      1h  Little Bilu has failed her exam. Furious at he...   9.2
# 19     5  1h 37m  Famous cabaret presented by Milan Gutovic wher...   9.4
# 20     6      1h  Titli's family prepares to go on a vacation to...   9.2
# 21    16    None                                               None   9.1
# 22    11  1h 58m                                               None   9.7
# 23    87    None  The wacky world of a television station's empl...   9.4
# 24     6    None                                               None   9.7
# 25     6    None                                               None   9.0
# 26     7     58m  Historian, educator, composer, and vocalist Dr...   9.7
# 27     7    None                                               None   9.8
# 28    84     36m                                               None   9.0
# 29    10  1h 40m                                               None   9.1
# 30    15    None                                               None   9.4
# 31     9     54m  Writer-director Gary Hawkins's first "Rough So...   9.5
# 32    45  2h 17m                                               None   9.2
#
#                                                   URL
# 0   https://www.imdb.com/title/tt0292912/?ref_=sr_t_1
# 1   https://www.imdb.com/title/tt0254193/?ref_=sr_t_2
# 2   https://www.imdb.com/title/tt0101350/?ref_=sr_t_3
# 3   https://www.imdb.com/title/tt0121873/?ref_=sr_t_4
# 4   https://www.imdb.com/title/tt0426421/?ref_=sr_t_5
# 5   https://www.imdb.com/title/tt2251404/?ref_=sr_t_6
# 6   https://www.imdb.com/title/tt0310358/?ref_=sr_t_7
# 7   https://www.imdb.com/title/tt0263922/?ref_=sr_t_8
# 8   https://www.imdb.com/title/tt0271803/?ref_=sr_t_9
# 9   https://www.imdb.com/title/tt0353493/?ref_=sr_...
# 10  https://www.imdb.com/title/tt0285991/?ref_=sr_...
# 11  https://www.imdb.com/title/tt0099945/?ref_=sr_...
# 12  https://www.imdb.com/title/tt0199757/?ref_=sr_...
# 13  https://www.imdb.com/title/tt0104980/?ref_=sr_...
# 14  https://www.imdb.com/title/tt0285278/?ref_=sr_...
# 15  https://www.imdb.com/title/tt0315242/?ref_=sr_...
# 16  https://www.imdb.com/title/tt0104386/?ref_=sr_...
# 17  https://www.imdb.com/title/tt0104950/?ref_=sr_...
# 18  https://www.imdb.com/title/tt6596518/?ref_=sr_...
# 19  https://www.imdb.com/title/tt9580170/?ref_=sr_...
# 20  https://www.imdb.com/title/tt6605464/?ref_=sr_...
# 21  https://www.imdb.com/title/tt0247717/?ref_=sr_...
# 22  https://www.imdb.com/title/tt1720086/?ref_=sr_...
# 23  https://www.imdb.com/title/tt0250823/?ref_=sr_...
# 24  https://www.imdb.com/title/tt0102923/?ref_=sr_...
# 25  https://www.imdb.com/title/tt0145862/?ref_=sr_...
# 26  https://www.imdb.com/title/tt0288227/?ref_=sr_...
# 27  https://www.imdb.com/title/tt6950126/?ref_=sr_...
# 28  https://www.imdb.com/title/tt0482154/?ref_=sr_...
# 29  https://www.imdb.com/title/tt0334882/?ref_=sr_...
# 30  https://www.imdb.com/title/tt2325639/?ref_=sr_...
# 31  https://www.imdb.com/title/tt0379966/?ref_=sr_...
# 32  https://www.imdb.com/title/tt0254824/?ref_=sr_...

# %% [markdown]
# **Hint**
#
# Your first mission is to familiarize yourself with the IMDb advanced search page. Head over to [IMDb advanced search](https://www.imdb.com/search/title/) and input the following parameters, keeping all other fields to their default values or blank:
#
# - **Title Type**: Feature film
# - **Release date**: From 1990 to 1992 (Note: You don't need to specify the day and month)
# - **User Rating**: 7.5 to -
#
# Upon searching, you'll land on a page showcasing a list of movies, each displaying vital details such as the title, release year, and crew information. Your task is to scrape this treasure trove of data.
#
# Carefully examine the resulting URL and construct your own URL to include all the necessary parameters for filtering the movies.

# %% [markdown]
# ---
#
# **Best of luck! Immerse yourself in the world of movies and may the data be with you!**

# %% [markdown]
# **Important note**:
#
# In the fast-changing online world, websites often get updates and make changes. When you try this lab, the IMDb website might be different from what we expect.
#
# If you run into problems because of these changes, like new rules or things that stop you from getting data, don't worry! Instead, get creative.
#
# You can choose another website that interests you and is good for scraping data. Websites like Wikipedia or The New York Times are good options. The main goal is still the same: get useful data and learn how to scrape it from a website that you find interesting. It's a chance to practice your web scraping skills and explore a source of information you like.

# %% [markdown]
# ## BONUS
#
# The search results span multiple pages, housing a total of 631 movies in our example with each page displaying 50 movies at most. To scrape data seamlessly from all pages, you'll need to dive deep into the structure of the URLs generated with each "Next" click.
#
# Take a close look at the following URLs:
# - First page:
#   ```
#   https://www.imdb.com/search/title/?title_type=feature&release_date=1990-01-01,1992-12-31&user_rating=7.5,
#   ```
# - Second page:
#   ```
#   https://www.imdb.com/search/title/?title_type=feature&release_date=1990-01-01,1992-12-31&user_rating=7.5,&start=51&ref_=adv_nxt
#   ```
# - Third page:
#   ```
#   https://www.imdb.com/search/title/?title_type=feature&release_date=1990-01-01,1992-12-31&user_rating=7.5,&start=101&ref_=adv_nxt
#   ```
#
# You should notice a pattern. There is a `start` parameter incrementing by 50 with each page, paired with a constant `ref_` parameter holding the value "adv_nxt".
#
# Modify your script so it's capable of iterating over all available pages to fetch data on all the 631 movies (631 is the total number of movies in the proposed example).

# %%
# We no longer need to create the loop to go trough the pages. We have to use selenium!!

# %%
# we will need a few extra libraries for selenium
#pip install selenium
#pip install webdriver-manager==3.0.0

# %%
# Your solution goes here
from selenium import webdriver 
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.opera.options import Options
from selenium.webdriver.chrome.service import Service
from webdriver_manager.opera import OperaDriverManager
import time

def scrape_imdb_with_selenium(title_type,user_rating,start_date,end_date):
    title_type_clean = title_type.lower().strip().replace(' ','_')
    date_time_start = datetime.strptime(start_date,'%B %d, %Y')
    string_start = datetime.strftime(date_time_start,"%Y-%m-%d")
    date_time_end = datetime.strptime(end_date,'%B %d, %Y')
    string_end = datetime.strftime(date_time_end,"%Y-%m-%d")
    
    url=f'https://www.imdb.com/search/title/?title_type={title_type_clean}&user_rating={user_rating},10&release_date={string_start},{string_end}'
    driver = webdriver.opera.webdriver.OperaDriver(OperaDriverManager().install())#opens a opera browser window, we are using opera but any browser could be used
    driver.get(url)
    try:
        button = driver.find_element_by_css_selector('button.ipc-see-more__button')
        while button:
            try:
                button.click()
                
            except:
            
                pass
                
            finally:
                time.sleep(2)
                button = driver.find_element_by_css_selector('button.ipc-see-more__button')
    except NoSuchElementException:
        pass
    
    soup = BeautifulSoup(driver.page_source)
    driver.quit()
    title_position = soup.find_all('h3')[:-1]
    position = [t.text.split('.')[0] for t in title_position]
    title = [t.text.split('. ',1)[1] for t in title_position]
    years = [div.find('span').text for div in soup.find_all('div',attrs={'class':'sc-43986a27-7 dBkaPT dli-title-metadata'})]
    title_urls = ['https://www.imdb.com' + u.get('href') for u in soup.select('a.ipc-title-link-wrapper')]
    votes = [div.text.replace('Votes','').replace(',','') for div in soup.find_all('div', class_="sc-53c98e73-0 kRnqtn")]
    runtime = []
    for div in soup.find_all('div',attrs={'class':"sc-43986a27-7 dBkaPT dli-title-metadata"}):
        try:
            runtime.append(div.find_all('span')[1].text)
        except:
            runtime.append(None)
    
    description =[]
    for l in soup.find_all('li',attrs={'class':"ipc-metadata-list-summary-item"}):
        try:
            description.append(l.find('div', attrs={'class':"ipc-html-content-inner-div"}).text)
        except:
            description.append(None)
    stars = [stars.get('aria-label').split(': ')[1] for stars in soup.find_all('span',attrs ={'class':"ipc-rating-star ipc-rating-star--base ipc-rating-star--imdb ratingGroup--imdb-rating"})]
    #stars = [stars.text for stars in soup.find_all('div',attrs={'class':"sc-e3e7b191-0 jlKVfJ sc-43986a27-2 bvCMEK dli-ratings-container"})]
    df = pd.DataFrame({'Position':position,'Title':title,'Year of Release':years,
                 'Votes':votes,'Runtime':runtime,'Decription':description,
                  'Stars':stars,'URL':title_urls})
    return df

# %%
scrape_imdb_with_selenium('Short',7.5,'January 1, 1990','December 31, 1992')
# Out:
#     Position                                Title Year of Release Votes  \
# 0          1               Mr. Bean Takes an Exam            1991    85
# 1          2                            Knock Out            1992     7
# 2          3                          Anima Mundi            1991  1331
# 3          4                       World of Glory            1991  2478
# 4          5                             12:01 PM            1990  1481
# ..       ...                                  ...             ...   ...
# 262      263                          Cuny Island            1991    10
# 263      264                   Jump, Venus! Jump!            1992    29
# 264      265                     Our Planet Earth            1991     6
# 265      266                           Przez pole            1992     9
# 266      267  Carl G. Jung or Lapis Philosophorum            1991    12
#
#     Runtime                                         Decription Stars  \
# 0        9m  Mr. Bean realizes he doesn't know the answers ...   8.2
# 1       19m                                               None   8.1
# 2       28m  Image and music are intertwined in this third ...   7.5
# 3       14m  After witnessing an act of unprecedented viole...   7.5
# 4       25m  Poor Myron Castleman is stuck reliving the sam...   7.6
# ..      ...                                                ...   ...
# 262     18m                                               None   8.4
# 263      3m                                               None   8.2
# 264     23m  Over 200 human beings from a dozen countries h...   9.4
# 265     16m                                               None   7.8
# 266      4m                                               None   7.9
#
#                                                    URL
# 0    https://www.imdb.com/title/tt16358846/?ref_=sr...
# 1    https://www.imdb.com/title/tt0104628/?ref_=sr_t_2
# 2    https://www.imdb.com/title/tt0101349/?ref_=sr_t_3
# 3    https://www.imdb.com/title/tt0102083/?ref_=sr_t_4
# 4    https://www.imdb.com/title/tt0098962/?ref_=sr_t_5
# ..                                                 ...
# 262  https://www.imdb.com/title/tt0255080/?ref_=sr_...
# 263  https://www.imdb.com/title/tt0448224/?ref_=sr_...
# 264  https://www.imdb.com/title/tt0803054/?ref_=sr_...
# 265  https://www.imdb.com/title/tt0433024/?ref_=sr_...
# 266  https://www.imdb.com/title/tt2517720/?ref_=sr_...
#
# [267 rows x 8 columns]
